# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Valerius Travasso**
# PCB assembly engineer

# %% [markdown]
# *I am interested in data science because I like thefact that it can be applied to various domains and is not restricitve on working with limited tools.There are manydifferent tools to work with and gives oppurtunity to leard different things while working*

# %% [markdown]
# ###Calculate sum of 1 plus  plus 3

# %%
1+2+3

# %% [markdown]
# Horizontal rule
# ***
# - buller1
# - bullet2
# - bullet3
#
#
# ~~strikethrough~~
